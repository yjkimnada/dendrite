# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import explained_variance_score

# %%
na4_true = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1.npy")[-20*50000:].reshape(20,50000)
na4_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h1_output.npz")["test"]
na4_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust4-60/mono/glm_s5_h1_output.npz")["test"]
na4_glm1_global = np.load("/media/hdd01/sklee/CA1_clust4-60/global/glm_s1_h1_output.npz")["test"]
na4_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h2_output.npz")["test"]
na4_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust4-60/mono/glm_s5_h2_output.npz")["test"]
na4_glm2_global = np.load("/media/hdd01/sklee/CA1_clust4-60/global/glm_s1_h2_output.npz")["test"]
na4_gru_hand = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/gru_s10_h20_output.npz")["test"]
na4_gru_mono = np.load("/media/hdd01/sklee/CA1_clust4-60/mono/gru_s5_h20_output.npz")["test"]
na4_gru_global = np.load("/media/hdd01/sklee/CA1_clust4-60/global/gru_s1_h20_output.npz")["test"]

nona4_true = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
nona4_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h1_output.npz")["test"]
nona4_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/mono/glm_s5_h1_output.npz")["test"]
nona4_glm1_global = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/global/glm_s1_h1_output.npz")["test"]
nona4_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h2_output.npz")["test"]
nona4_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/mono/glm_s5_h2_output.npz")["test"]
nona4_glm2_global = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/global/glm_s1_h2_output.npz")["test"]
nona4_gru_hand = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/gru_s10_h20_output.npz")["test"]
nona4_gru_mono = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/mono/gru_s5_h20_output.npz")["test"]
nona4_gru_global = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/global/gru_s1_h20_output.npz")["test"]

na8_true = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy")[-20*50000:].reshape(20,50000)
na8_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h1_output.npz")["test"]
na8_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust8-30/mono/glm_s9_h1_output.npz")["test"]
na8_glm1_global = np.load("/media/hdd01/sklee/CA1_clust8-30/global/glm_s1_h1_output.npz")["test"]
na8_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h2_output.npz")["test"]
na8_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust8-30/mono/glm_s9_h2_output.npz")["test"]
na8_glm2_global = np.load("/media/hdd01/sklee/CA1_clust8-30/global/glm_s1_h2_output.npz")["test"]
na8_gru_hand = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/gru_s14_h20_output.npz")["test"]
na8_gru_mono = np.load("/media/hdd01/sklee/CA1_clust8-30/mono/gru_s9_h20_output.npz")["test"]
na8_gru_global = np.load("/media/hdd01/sklee/CA1_clust8-30/global/gru_s1_h20_output.npz")["test"]

nona8_true = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
nona8_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h1_output.npz")["test"]
nona8_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/mono/glm_s9_h1_output.npz")["test"]
nona8_glm1_global = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/global/glm_s1_h1_output.npz")["test"]
nona8_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h2_output.npz")["test"]
nona8_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/mono/glm_s9_h2_output.npz")["test"]
nona8_glm2_global = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/global/glm_s1_h2_output.npz")["test"]
nona8_gru_hand = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/gru_s14_h20_output.npz")["test"]
nona8_gru_mono = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/mono/gru_s9_h20_output.npz")["test"]
nona8_gru_global = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/global/gru_s1_h20_output.npz")["test"]

na12_true = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy")[-20*50000:].reshape(20,50000)
na12_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h1_output.npz")["test"]
na12_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust12-20/mono/glm_s13_h1_output.npz")["test"]
na12_glm1_global = np.load("/media/hdd01/sklee/CA1_clust12-20/global/glm_s1_h1_output.npz")["test"]
na12_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h2_output.npz")["test"]
na12_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust12-20/mono/glm_s13_h2_output.npz")["test"]
na12_glm2_global = np.load("/media/hdd01/sklee/CA1_clust12-20/global/glm_s1_h2_output.npz")["test"]
na12_gru_hand = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/gru_s18_h20_output.npz")["test"]
na12_gru_mono = np.load("/media/hdd01/sklee/CA1_clust12-20/mono/gru_s13_h20_output.npz")["test"]
na12_gru_global = np.load("/media/hdd01/sklee/CA1_clust12-20/global/gru_s1_h20_output.npz")["test"]

nona12_true = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
nona12_glm1_hand = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h1_output.npz")["test"]
nona12_glm1_mono = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/mono/glm_s13_h1_output.npz")["test"]
nona12_glm1_global = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/global/glm_s1_h1_output.npz")["test"]
nona12_glm2_hand = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h2_output.npz")["test"]
nona12_glm2_mono = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/mono/glm_s13_h2_output.npz")["test"]
nona12_glm2_global = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/global/glm_s1_h2_output.npz")["test"]
nona12_gru_hand = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/gru_s18_h20_output.npz")["test"]
nona12_gru_mono = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/mono/gru_s13_h20_output.npz")["test"]
nona12_gru_global = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/global/gru_s1_h20_output.npz")["test"]

# %%
na4_true_var_exp = np.zeros((20,9))
nona4_true_var_exp = np.zeros((20,9))
na8_true_var_exp = np.zeros((20,9))
nona8_true_var_exp = np.zeros((20,9))
na12_true_var_exp = np.zeros((20,9))
nona12_true_var_exp = np.zeros((20,9))

for i in range(20):
    na4_true_var_exp[i,2] = explained_variance_score(na4_true[i], na4_glm1_hand[i])
    na4_true_var_exp[i,1] = explained_variance_score(na4_true[i], na4_glm1_mono[i])
    na4_true_var_exp[i,0] = explained_variance_score(na4_true[i], na4_glm1_global[i])
    na4_true_var_exp[i,5] = explained_variance_score(na4_true[i], na4_glm2_hand[i])
    na4_true_var_exp[i,4] = explained_variance_score(na4_true[i], na4_glm2_mono[i])
    na4_true_var_exp[i,3] = explained_variance_score(na4_true[i], na4_glm2_global[i])
    na4_true_var_exp[i,8] = explained_variance_score(na4_true[i], na4_gru_hand[i])
    na4_true_var_exp[i,7] = explained_variance_score(na4_true[i], na4_gru_mono[i])
    na4_true_var_exp[i,6] = explained_variance_score(na4_true[i], na4_gru_global[i])
    nona4_true_var_exp[i,2] = explained_variance_score(nona4_true[i], nona4_glm1_hand[i])
    nona4_true_var_exp[i,1] = explained_variance_score(nona4_true[i], nona4_glm1_mono[i])
    nona4_true_var_exp[i,0] = explained_variance_score(nona4_true[i], nona4_glm1_global[i])
    nona4_true_var_exp[i,5] = explained_variance_score(nona4_true[i], nona4_glm2_hand[i])
    nona4_true_var_exp[i,4] = explained_variance_score(nona4_true[i], nona4_glm2_mono[i])
    nona4_true_var_exp[i,3] = explained_variance_score(nona4_true[i], nona4_glm2_global[i])
    nona4_true_var_exp[i,8] = explained_variance_score(nona4_true[i], nona4_gru_hand[i])
    nona4_true_var_exp[i,7] = explained_variance_score(nona4_true[i], nona4_gru_mono[i])
    nona4_true_var_exp[i,6] = explained_variance_score(nona4_true[i], nona4_gru_global[i])
    
    na8_true_var_exp[i,2] = explained_variance_score(na8_true[i], na8_glm1_hand[i])
    na8_true_var_exp[i,1] = explained_variance_score(na8_true[i], na8_glm1_mono[i])
    na8_true_var_exp[i,0] = explained_variance_score(na8_true[i], na8_glm1_global[i])
    na8_true_var_exp[i,5] = explained_variance_score(na8_true[i], na8_glm2_hand[i])
    na8_true_var_exp[i,4] = explained_variance_score(na8_true[i], na8_glm2_mono[i])
    na8_true_var_exp[i,3] = explained_variance_score(na8_true[i], na8_glm2_global[i])
    na8_true_var_exp[i,8] = explained_variance_score(na8_true[i], na8_gru_hand[i])
    na8_true_var_exp[i,7] = explained_variance_score(na8_true[i], na8_gru_mono[i])
    na8_true_var_exp[i,6] = explained_variance_score(na8_true[i], na8_gru_global[i])
    nona8_true_var_exp[i,2] = explained_variance_score(nona8_true[i], nona8_glm1_hand[i])
    nona8_true_var_exp[i,1] = explained_variance_score(nona8_true[i], nona8_glm1_mono[i])
    nona8_true_var_exp[i,0] = explained_variance_score(nona8_true[i], nona8_glm1_global[i])
    nona8_true_var_exp[i,5] = explained_variance_score(nona8_true[i], nona8_glm2_hand[i])
    nona8_true_var_exp[i,4] = explained_variance_score(nona8_true[i], nona8_glm2_mono[i])
    nona8_true_var_exp[i,3] = explained_variance_score(nona8_true[i], nona8_glm2_global[i])
    nona8_true_var_exp[i,8] = explained_variance_score(nona8_true[i], nona8_gru_hand[i])
    nona8_true_var_exp[i,7] = explained_variance_score(nona8_true[i], nona8_gru_mono[i])
    nona8_true_var_exp[i,6] = explained_variance_score(nona8_true[i], nona8_gru_global[i])
    
    na12_true_var_exp[i,2] = explained_variance_score(na12_true[i], na12_glm1_hand[i])
    na12_true_var_exp[i,1] = explained_variance_score(na12_true[i], na12_glm1_mono[i])
    na12_true_var_exp[i,0] = explained_variance_score(na12_true[i], na12_glm1_global[i])
    na12_true_var_exp[i,5] = explained_variance_score(na12_true[i], na12_glm2_hand[i])
    na12_true_var_exp[i,4] = explained_variance_score(na12_true[i], na12_glm2_mono[i])
    na12_true_var_exp[i,3] = explained_variance_score(na12_true[i], na12_glm2_global[i])
    na12_true_var_exp[i,8] = explained_variance_score(na12_true[i], na12_gru_hand[i])
    na12_true_var_exp[i,7] = explained_variance_score(na12_true[i], na12_gru_mono[i])
    na12_true_var_exp[i,6] = explained_variance_score(na12_true[i], na12_gru_global[i])
    nona12_true_var_exp[i,2] = explained_variance_score(nona12_true[i], nona12_glm1_hand[i])
    nona12_true_var_exp[i,1] = explained_variance_score(nona12_true[i], nona12_glm1_mono[i])
    nona12_true_var_exp[i,0] = explained_variance_score(nona12_true[i], nona12_glm1_global[i])
    nona12_true_var_exp[i,5] = explained_variance_score(nona12_true[i], nona12_glm2_hand[i])
    nona12_true_var_exp[i,4] = explained_variance_score(nona12_true[i], nona12_glm2_mono[i])
    nona12_true_var_exp[i,3] = explained_variance_score(nona12_true[i], nona12_glm2_global[i])
    nona12_true_var_exp[i,8] = explained_variance_score(nona12_true[i], nona12_gru_hand[i])
    nona12_true_var_exp[i,7] = explained_variance_score(nona12_true[i], nona12_gru_mono[i])
    nona12_true_var_exp[i,6] = explained_variance_score(nona12_true[i], nona12_gru_global[i])

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"

fig = plt.figure(constrained_layout=True, figsize = (10,10))
gs = fig.add_gridspec(3,2, wspace=0.01, hspace=0.1)
ax1 = fig.add_subplot(gs[0,1])
ax2 = fig.add_subplot(gs[0,0])
ax3 = fig.add_subplot(gs[1,1])
ax4 = fig.add_subplot(gs[1,0])
ax5 = fig.add_subplot(gs[2,1])
ax6 = fig.add_subplot(gs[2,0])

colors = ["tab:purple", "tab:orange", "tab:cyan"]
# first boxplot pair
bp = ax1.boxplot(na4_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax1.boxplot(na4_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax1.boxplot(na4_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax1.set_xticks([2,6,10])
ax1.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax1.set_title("Na+ differential (4-cluster)", fontsize=12)
ax1.spines.right.set_visible(False)
ax1.spines.top.set_visible(False)
ax1.spines.bottom.set_visible(False)
ax1.tick_params(axis="x", length=0)
ax1.set_ylim(0.1,1)
ax1.set_yticks(np.arange(0.1,1.01,0.3))
hP, = ax1.plot(1,1,'tab:purple')
hO, = ax1.plot(1,1,'tab:orange')
hC, = ax1.plot(1,1,'tab:cyan')
ax1.legend((hP, hO, hC),('1 global', '1 background + n clustered', '5 background + n clustered'),
          frameon=False)
hP.set_visible(False)
hO.set_visible(False)
hC.set_visible(False)

# first boxplot pair
bp = ax2.boxplot(nona4_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax2.boxplot(nona4_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax2.boxplot(nona4_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax2.set_xticks([2,6,10])
ax2.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax2.set_title("No Na+ (4-cluster)", fontsize=12)
ax2.spines.right.set_visible(False)
ax2.spines.top.set_visible(False)
ax2.set_ylabel("variance explained", fontsize=12)
ax2.set_ylim(0.1,1)
ax2.set_yticks(np.arange(0.1,1.01,0.3))
ax2.spines.right.set_visible(False)
ax2.spines.top.set_visible(False)
ax2.spines.bottom.set_visible(False)
ax2.tick_params(axis="x", length=0)

ins = ax2.inset_axes([0.15,0.1,0.8,0.45])
# first boxplot pair
bp = ins.boxplot(nona4_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ins.boxplot(nona4_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ins.boxplot(nona4_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ins.set_xticks([])
ins.set_ylim(0.92,1)
ins.set_yticks(np.arange(0.92,1.001,0.02))

ins.spines.right.set_visible(False)
ins.spines.top.set_visible(False)
ins.spines.bottom.set_visible(False)
ins.tick_params(axis="x", length=0)

# first boxplot pair
bp = ax3.boxplot(na8_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax3.boxplot(na8_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax3.boxplot(na8_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax3.set_xticks([2,6,10])
ax3.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax3.set_title("Na+ differential (8-cluster)", fontsize=12)
ax3.spines.right.set_visible(False)
ax3.spines.top.set_visible(False)
ax3.spines.bottom.set_visible(False)
ax3.tick_params(axis="x", length=0)
ax3.set_ylim(0.1,1)
ax3.set_yticks(np.arange(0.1,1.01,0.3))
hP, = ax3.plot(1,1,'tab:purple')
hO, = ax3.plot(1,1,'tab:orange')
hC, = ax3.plot(1,1,'tab:cyan')
#ax3.legend((hP, hO, hC),('5 background + n clustered', '1 background + n clustered', '1 global'),
          #frameon=False)
hP.set_visible(False)
hO.set_visible(False)
hC.set_visible(False)

# first boxplot pair
bp = ax4.boxplot(nona8_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax4.boxplot(nona8_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax4.boxplot(nona8_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax4.set_xticks([2,6,10])
ax4.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax4.set_title("No Na+ (8-cluster)", fontsize=12)
ax4.spines.right.set_visible(False)
ax4.spines.top.set_visible(False)
ax4.spines.bottom.set_visible(False)
ax4.tick_params(axis="x", length=0)
ax4.set_ylabel("variance explained", fontsize=12)
ax4.set_ylim(0.1,1)
ax4.set_yticks(np.arange(0.1,1.01,0.3))


ins = ax4.inset_axes([0.15,0.1,0.8,0.45])
# first boxplot pair
bp = ins.boxplot(nona8_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ins.boxplot(nona8_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ins.boxplot(nona8_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ins.set_xticks([])
ins.set_ylim(0.94,1)
ins.set_yticks(np.arange(0.94,1.001,0.02))
ins.spines.right.set_visible(False)
ins.spines.top.set_visible(False)
ins.spines.bottom.set_visible(False)
ins.tick_params(axis="x", length=0)

# first boxplot pair
bp = ax5.boxplot(na12_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax5.boxplot(na12_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax5.boxplot(na12_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax5.set_xticks([2,6,10])
ax5.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax5.set_title("Na+ differential (12-cluster)", fontsize=12)
ax5.set_ylim(0,0.8)
ax5.spines.right.set_visible(False)
ax5.spines.top.set_visible(False)
ax5.spines.bottom.set_visible(False)
ax5.tick_params(axis="x", length=0)
hP, = ax5.plot(1,1,'tab:purple')
hO, = ax5.plot(1,1,'tab:orange')
hC, = ax5.plot(1,1,'tab:cyan')
#ax5.legend((hP, hO, hC),('5 background + n clustered', '1 background + n clustered', '1 global'),
          #frameon=False)
hP.set_visible(False)
hO.set_visible(False)
hC.set_visible(False)
ax5.set_ylim(0,1)

# first boxplot pair
bp = ax6.boxplot(nona12_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ax6.boxplot(nona12_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ax6.boxplot(nona12_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ax6.set_xticks([2,6,10])
ax6.set_xticklabels(["GLM\n(1-plex)", "GLM\n(2-plex)", "GRU"], fontsize=12)
ax6.set_title("No Na+ (12-cluster)", fontsize=12)
ax6.spines.right.set_visible(False)
ax6.spines.top.set_visible(False)
ax6.spines.bottom.set_visible(False)
ax6.tick_params(axis="x", length=0)
ax6.set_ylabel("variance explained", fontsize=12)
ax6.set_ylim(0,1)

ins = ax6.inset_axes([0.15,0.1,0.8,0.45])
# first boxplot pair
bp = ins.boxplot(nona12_true_var_exp[:,:3], positions = [1,2,3], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
# second boxplot pair
bp = ins.boxplot(nona12_true_var_exp[:,3:6], positions = [5,6,7], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black") 
# third boxplot pair
bp = ins.boxplot(nona12_true_var_exp[:,6:9], positions = [9,10,11], widths = 0.6, patch_artist=True)
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.5)
for patch in bp["medians"]:
    patch.set_color("black")
ins.set_xticks([])
ins.set_ylim(0.94,1)
ins.set_yticks(np.arange(0.94, 1.001,0.02))
ins.spines.right.set_visible(False)
ins.spines.top.set_visible(False)
ins.spines.bottom.set_visible(False)
ins.tick_params(axis="x", length=0)

fig.tight_layout()
#plt.show()
#fig.savefig("/home/sklee/dendrite/fig_supp3/fig_supp3_raw.pdf", bbox_inches="tight", transparent=True)
# Out:
# <ipython-input-16-bc7b77b0cfb7>:321: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

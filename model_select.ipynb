# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tnrange

# %% [markdown]
# # Autocorr

# %%
true4_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy"))
true4_nona = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[:,:50000]
true4_diff = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1_set1.npy").reshape(1000,50000)

true8_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true8_nona = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true8_diff = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy").reshape(1000,50000)

true12_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true12_nona = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true12_diff = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy").reshape(1000,50000)

one4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h1_Vall.npy") + true4_nona_mean
two4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h2_Vall.npy") + true4_nona_mean
gru4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/gru_s10_h20_Vall.npy") + true4_nona_mean
one4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h1_Vall.npy")
two4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h2_Vall.npy")
gru4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/gru_s10_h20_Vall.npy")

one8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h1_Vall.npy") + true8_nona_mean
two8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h2_Vall.npy") + true8_nona_mean
gru8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/gru_s14_h20_Vall.npy") + true8_nona_mean
one8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h1_Vall.npy")
two8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h2_Vall.npy")
gru8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/gru_s14_h20_Vall.npy")

one12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h1_Vall.npy") + true12_nona_mean
two12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h2_Vall.npy") + true12_nona_mean
gru12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/gru_s18_h20_Vall.npy") + true12_nona_mean
one12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h1_Vall.npy")
two12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h2_Vall.npy")
gru12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/gru_s18_h20_Vall.npy")

# %%
errors = np.empty((2,9,1000,50000))

errors[0,0] = (true4_nona - one4_nona_test)
errors[0,1] = (true4_nona - two4_nona_test)
errors[0,2] = (true4_nona - gru4_nona_test)
errors[0,3] = (true8_nona - one8_nona_test)
errors[0,4] = (true8_nona - two8_nona_test)
errors[0,5] = (true8_nona - gru8_nona_test)
errors[0,6] = (true12_nona - one12_nona_test)
errors[0,7] = (true12_nona - two12_nona_test)
errors[0,8] = (true12_nona - gru12_nona_test)

errors[1,0] = (true4_diff - one4_diff_test)
errors[1,1] = (true4_diff - two4_diff_test)
errors[1,2] = (true4_diff - gru4_diff_test)
errors[1,3] = (true8_diff - one8_diff_test)
errors[1,4] = (true8_diff - two8_diff_test)
errors[1,5] = (true8_diff - gru8_diff_test)
errors[1,6] = (true12_diff - one12_diff_test)
errors[1,7] = (true12_diff - two12_diff_test)
errors[1,8] = (true12_diff - gru12_diff_test)

# %%
delta_max = 2500
autocorr = np.zeros((2,9,delta_max))
sample_no = 10

for i in tnrange(delta_max):
    for j in range(2):
        for k in range(9):
            for l in range(sample_no):
                autocorr[j,k,i] += np.corrcoef(errors[j,k,l,:-delta_max],
                                              errors[j,k,l,i:-delta_max+i])[0][1] / sample_no
# Out:
# /tmp/ipykernel_30250/1147937819.py:5: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(delta_max):
#   0%|          | 0/2500 [00:00<?, ?it/s]

# %%
fig, axs = plt.subplots(nrows=2, ncols=9, figsize=(25,6))

titles = ["4: GLM 1-plex", "4: GLM 2-plex", "4: GRU",
         "8: GLM 1-plex", "8: GLM 2-plex", "8: GRU",
         "12: GLM 1-plex", "12: GLM 2-plex", "12: GRU",]

for row in range(2):
    for col in range(9):
        axs[row,col].plot(np.arange(delta_max)/5, autocorr[row,col])
        axs[row,col].set_title(titles[col])
        axs[row,col].set_xscale('log', base=10)
        axs[row,col].set_ylim(-0.2,1)
        axs[row,col].hlines(y=0, xmin=0, xmax=delta_max/5, linestyle="--", linewidth=1, color="gray")
        
        
fig.tight_layout()
#plt.show()
#plt.savefig("./error_autocorr.png", dpi=200, transparent=False)

# %% [markdown]
# # Marg

# %%
true4_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy"))
true4_nona = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[:,:50000]
true4_diff = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1_set1.npy").reshape(1000,50000)

true8_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true8_nona = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true8_diff = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy").reshape(1000,50000)

true12_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true12_nona = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true12_diff = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy").reshape(1000,50000)

one4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h1_Vall.npy") + true4_nona_mean
two4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h2_Vall.npy") + true4_nona_mean
gru4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/gru_s10_h20_Vall.npy") + true4_nona_mean
one4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h1_Vall.npy")
two4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h2_Vall.npy")
gru4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/gru_s10_h20_Vall.npy")

one8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h1_Vall.npy") + true8_nona_mean
two8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h2_Vall.npy") + true8_nona_mean
gru8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/gru_s14_h20_Vall.npy") + true8_nona_mean
one8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h1_Vall.npy")
two8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h2_Vall.npy")
gru8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/gru_s14_h20_Vall.npy")

one12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h1_Vall.npy") + true12_nona_mean
two12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h2_Vall.npy") + true12_nona_mean
gru12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/gru_s18_h20_Vall.npy") + true12_nona_mean
one12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h1_Vall.npy")
two12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h2_Vall.npy")
gru12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/gru_s18_h20_Vall.npy")

# %%
errors = np.empty((2,9,1000,50000))

errors[0,0] = (true4_nona - one4_nona_test)
errors[0,1] = (true4_nona - two4_nona_test)
errors[0,2] = (true4_nona - gru4_nona_test)
errors[0,3] = (true8_nona - one8_nona_test)
errors[0,4] = (true8_nona - two8_nona_test)
errors[0,5] = (true8_nona - gru8_nona_test)
errors[0,6] = (true12_nona - one12_nona_test)
errors[0,7] = (true12_nona - two12_nona_test)
errors[0,8] = (true12_nona - gru12_nona_test)

errors[1,0] = (true4_diff - one4_diff_test)
errors[1,1] = (true4_diff - two4_diff_test)
errors[1,2] = (true4_diff - gru4_diff_test)
errors[1,3] = (true8_diff - one8_diff_test)
errors[1,4] = (true8_diff - two8_diff_test)
errors[1,5] = (true8_diff - gru8_diff_test)
errors[1,6] = (true12_diff - one12_diff_test)
errors[1,7] = (true12_diff - two12_diff_test)
errors[1,8] = (true12_diff - gru12_diff_test)

# %%
histograms = np.empty((2,9,100))
edges = np.empty((2,9,101))

for i in tnrange(2):
    for j in tnrange(9):
        for k in range(101):
            edges[i,j,k] = np.quantile(errors[i,j].flatten(), 0.01*k)
        hist, _ = np.histogram(errors[i,j].flatten(), bins=edges[i,j], density=True)
        histograms[i,j] = hist
# Out:
# /tmp/ipykernel_18246/1041409273.py:4: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(2):
#   0%|          | 0/2 [00:00<?, ?it/s]
# /tmp/ipykernel_18246/1041409273.py:5: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for j in tnrange(9):
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
np.save("/media/hdd01/sklee/4B_error_histograms.npy", histograms)
np.save("/media/hdd01/sklee/4B_error_bins.npy", edges)

# %% [markdown]
# # 4B

# %%
true4_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy"))
true4_nona = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[:,:50000]
true4_diff = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1_set1.npy").reshape(1000,50000)

true8_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true8_nona = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true8_diff = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy").reshape(1000,50000)

true12_nona_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true12_nona = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000]
true12_diff = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy").reshape(1000,50000)

one4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h1_Vall.npy") + true4_nona_mean
two4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/glm_s10_h2_Vall.npy") + true4_nona_mean
gru4_nona_test = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/gru_s10_h20_Vall.npy") + true4_nona_mean
one4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h1_Vall.npy")
two4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/glm_s10_h2_Vall.npy")
gru4_diff_test = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/gru_s10_h20_Vall.npy")

one8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h1_Vall.npy") + true8_nona_mean
two8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/glm_s14_h2_Vall.npy") + true8_nona_mean
gru8_nona_test = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/gru_s14_h20_Vall.npy") + true8_nona_mean
one8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h1_Vall.npy")
two8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/glm_s14_h2_Vall.npy")
gru8_diff_test = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/gru_s14_h20_Vall.npy")

one12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h1_Vall.npy") + true12_nona_mean
two12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/glm_s18_h2_Vall.npy") + true12_nona_mean
gru12_nona_test = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/gru_s18_h20_Vall.npy") + true12_nona_mean
one12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h1_Vall.npy")
two12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/glm_s18_h2_Vall.npy")
gru12_diff_test = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/gru_s18_h20_Vall.npy")

histograms = np.load("/media/hdd01/sklee/4B_error_histograms.npy")
edges = np.load("/media/hdd01/sklee/4B_error_bins.npy")

rss = np.zeros((2,9,1000*50000)) # not actually rss just diff

rss[0,0] = (true4_nona - one4_nona_test).flatten()
rss[0,1] = (true4_nona - two4_nona_test).flatten()
rss[0,2] = (true4_nona - gru4_nona_test).flatten()
rss[0,3] = (true8_nona - one8_nona_test).flatten()
rss[0,4] = (true8_nona - two8_nona_test).flatten()
rss[0,5] = (true8_nona - gru8_nona_test).flatten()
rss[0,6] = (true12_nona - one12_nona_test).flatten()
rss[0,7] = (true12_nona - two12_nona_test).flatten()
rss[0,8] = (true12_nona - gru12_nona_test).flatten()

rss[1,0] = (true4_diff - one4_diff_test).flatten()
rss[1,1] = (true4_diff - two4_diff_test).flatten()
rss[1,2] = (true4_diff - gru4_diff_test).flatten()
rss[1,3] = (true8_diff - one8_diff_test).flatten()
rss[1,4] = (true8_diff - two8_diff_test).flatten()
rss[1,5] = (true8_diff - gru8_diff_test).flatten()
rss[1,6] = (true12_diff - one12_diff_test).flatten()
rss[1,7] = (true12_diff - two12_diff_test).flatten()
rss[1,8] = (true12_diff - gru12_diff_test).flatten()

# %%
bic = np.zeros((2,9,2))
"""
one4_param = 2821
two4_param = 3441
gru4_param = 16211
one8_param = 3069
two8_param = 3937
gru8_param = 21815
one12_param = 3317
two12_param = 4433
gru12_param = 27419
"""
param_no = np.asarray([2821, 3441, 16211,
                      3069, 3937, 21815,
                      3317, 4433, 27419])
#param_no += 101
param_no = np.tile(param_no.reshape(1,-1), (2,1))

#bic[0,:,0] = -50000/2 * np.log(1-var_exp[0])
#bic[1,:,0] = -10*50000/2 * np.log(1-var_exp[1])
bic[0,:,0] = -50000/2 * np.log(np.mean(rss[0]**2, -1))
bic[1,:,0] = -50000*10/2 * np.log(np.mean(rss[1]**2, -1))
#bic[0,:,0] = np.mean(lls[0], -1) * 50000
#bic[1,:,0] = np.mean(lls[1], -1) * 10*50000

#bic[0,:,1] = - param_no[0]/2*np.log(20000)
#bic[1,:,1] = - param_no[1]/2*np.log(10*50000)
bic[0,:,1] = - param_no[0]
bic[1,:,1] = - param_no[1]

# %%
fig, axs = plt.subplots(nrows=2, figsize=(12,8))

#axs[0].bar([1,2,3,5,6,7,9,10,11], bic[0,:,0] / 50000, label="log lik")
#axs[1].bar([1,2,3,5,6,7,9,10,11], bic[1,:,0] / 10/50000)
#axs[0].bar([1,2,3,5,6,7,9,10,11], bic[0,:,1] / 50000, label="penalty")
#axs[1].bar([1,2,3,5,6,7,9,10,11], bic[1,:,1] / 10/50000)
axs[0].bar([1,2,3,5,6,7,9,10,11], (bic[0,:,0] + bic[0,:,1]) / 50000)
axs[1].bar([1,2,3,5,6,7,9,10,11], (bic[1,:,0] + bic[1,:,1]) / 50000 / 10)
#axs[0].legend()

axs[0].set_xticks([1,2,3,5,6,7,9,10,11])
axs[0].set_xticklabels(["1-plex", '2-plex', 'GRU',
                       "1-plex", '2-plex', 'GRU',
                       "1-plex", '2-plex', 'GRU'])
axs[1].set_xticks([1,2,3,5,6,7,9,10,11])
axs[1].set_xticklabels(["1-plex", '2-plex', 'GRU',
                       "1-plex", '2-plex', 'GRU',
                       "1-plex", '2-plex', 'GRU'])

axs[0].set_ylabel("Normalized BIC (higher is better)")
axs[1].set_ylabel("Normalized BIC (higher is better)")

axs[0].set_title("V_noNa")
axs[1].set_title("V_Na")

fig.suptitle("Fig. 4B", fontsize=18, y=0.95)
# Out:
# Text(0.5, 0.95, 'Fig. 4B')

# %% [markdown]
# # 5B

# %%
na4_true = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1_set1.npy")[-20*50000:].reshape(20,50000)
na4_gru_hand = np.load("/media/hdd01/sklee/CA1_clust4-60/hand/gru_s10_h20_output.npz")["test"]
na4_gru_global = np.load("/media/hdd01/sklee/CA1_clust4-60/global/gru_s1_h20_output.npz")["test"]

nona4_true = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[-20:,:50000]
nona4_true -= np.mean(np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[:,:50000])
nona4_gru_hand = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/hand/gru_s10_h20_output.npz")["test"]
nona4_gru_global = np.load("/media/hdd01/sklee/CA1_clust4-60_noNA/global/gru_s1_h20_output.npz")["test"]

na8_true = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy")[-20*50000:].reshape(20,50000)
na8_gru_hand = np.load("/media/hdd01/sklee/CA1_clust8-30/hand/gru_s14_h20_output.npz")["test"]
na8_gru_global = np.load("/media/hdd01/sklee/CA1_clust8-30/global/gru_s1_h20_output.npz")["test"]

nona8_true = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
nona8_true -= np.mean(np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000])
nona8_gru_hand = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/hand/gru_s14_h20_output.npz")["test"]
nona8_gru_global = np.load("/media/hdd01/sklee/CA1_clust8-30_noNA/global/gru_s1_h20_output.npz")["test"]

na12_true = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy")[-20*50000:].reshape(20,50000)
na12_gru_hand = np.load("/media/hdd01/sklee/CA1_clust12-20/hand/gru_s18_h20_output.npz")["test"]
na12_gru_global = np.load("/media/hdd01/sklee/CA1_clust12-20/global/gru_s1_h20_output.npz")["test"]

nona12_true = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
nona12_true -= np.mean(np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_noDendNa_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[:,:50000])
nona12_gru_hand = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/hand/gru_s18_h20_output.npz")["test"]
nona12_gru_global = np.load("/media/hdd01/sklee/CA1_clust12-20_noNA/global/gru_s1_h20_output.npz")["test"]

# %%
bic = np.zeros((2,6))
"""
gru4_param = 16211
gru8_param = 21815
gru12_param = 27419
"""
param_no = np.asarray([16211, 3602,
                       21815, 3602,
                       27419, 3602])
param_no = np.tile(param_no.reshape(1,-1), (2,1))
rss = np.zeros((2,6,20*50000)) # not actually rss just diff

rss[0,0] = (nona4_true - nona4_gru_global).flatten()
rss[0,1] = (nona4_true - nona4_gru_hand).flatten()
rss[0,2] = (nona8_true - nona8_gru_global).flatten()
rss[0,3] = (nona8_true - nona8_gru_hand).flatten()
rss[0,4] = (nona12_true - nona12_gru_global).flatten()
rss[0,5] = (nona12_true - nona12_gru_hand).flatten()

rss[1,0] = (na4_true - na4_gru_global).flatten()
rss[1,1] = (na4_true - na4_gru_hand).flatten()
rss[1,2] = (na8_true - na8_gru_global).flatten()
rss[1,3] = (na8_true - na8_gru_hand).flatten()
rss[1,4] = (na12_true - na12_gru_global).flatten()
rss[1,5] = (na12_true - na12_gru_hand).flatten()

var = np.mean(rss**2, -1)
std = np.sqrt(var)

bic[0] = -20*50000 * np.log(np.mean((rss[0])**2, -1)) - param_no[0]*np.log(20*50000)
bic[1] = -20*50000 * np.log(np.mean((rss[1])**2, -1)) - param_no[1]*np.log(20*50000)

# %%
fig, axs = plt.subplots(nrows=2, figsize=(10,7))

axs[0].bar([1,2,4,5,7,8], bic[0])
axs[1].bar([1,2,4,5,7,8], bic[1])

axs[0].set_ylabel("BIC (higher is better)")
axs[1].set_ylabel("BIC (higher is better)")

axs[0].set_title("V_noNa")
axs[1].set_title("V_Na")

axs[0].set_xticks([1,2,4,5,7,8])
axs[0].set_xticklabels(['global', "multi",
                       'global', "multi",
                       'global', "multi"])
axs[1].set_xticks([1,2,4,5,7,8])
axs[1].set_xticklabels(['global', "multi",
                       'global', "multi",
                       'global', "multi"])

fig.suptitle("Fig. 5B", fontsize=18, y=0.95)
# Out:
# Text(0.5, 0.95, 'Fig. 5B')

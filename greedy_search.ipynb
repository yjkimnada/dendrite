# %%
import numpy as np
import torch
from greedy_search import Greedy_Search
import matplotlib.pyplot as plt

# %%
base_dir = "/media/hdd01/sklee/"
experiment = "clust4-60"
cell_type = "CA1"

E_neural_file = "Espikes_neural.npy"
I_neural_file = "Ispikes_neural.npy"
V_file = "vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep10_stimseed1.npy"
Z_file = "spk_loc.npy"

# %%
model_type = "alpha_rootspike"
max_sub = 7
T_train = 60 * 1000 * 5
T_test = 10 * 1000 * 5
T_no = 500
save_dir = base_dir+cell_type+"_"+experiment+"/greedy/"
device = torch.device("cuda")
iter_no = 15000
batch_size = 100000
epoch_no = 15

# %%
E_neural = np.load(base_dir+cell_type+"_"+experiment+"/data/"+E_neural_file)
I_neural = np.load(base_dir+cell_type+"_"+experiment+"/data/"+I_neural_file)
V = np.load(base_dir+cell_type+"_"+experiment+"/data/"+V_file)[:,:50000].flatten()
Z = np.load(base_dir+cell_type+"_"+experiment+"/data/"+Z_file).flatten()

E_neural = torch.from_numpy(E_neural)
I_neural = torch.from_numpy(I_neural)
V = torch.from_numpy(V)
Z = torch.from_numpy(Z)

# %%
gs = Greedy_Search(model_type, max_sub, V, Z, E_neural, I_neural, T_train, T_test,
                T_no, iter_no, batch_size, epoch_no, device, save_dir)

# %%
gs.search()
# Out:
# ...
# VAR EXP: 0.88917 GAUSS: 0.10002 BCE: 0.01542
# GOOD:  4 BAD:  113
# 2 SUB:  [0.11544224]
# CUMULATIVE:  [0.11544224]
# ...
# VAR EXP: 0.89565 GAUSS: 0.09449 BCE: 0.01444
# GOOD:  9 BAD:  94
# ...
# VAR EXP: 0.89443 GAUSS: 0.09493 BCE: 0.01556
# GOOD:  10 BAD:  128
# 3 SUB:  [0.10892908 0.11049799]
# CUMULATIVE:  [0.11544224 0.10892908]
# ...
# VAR EXP: 0.90494 GAUSS: 0.08565 BCE: 0.0143
# GOOD:  6 BAD:  103
# ...
# VAR EXP: 0.8985 GAUSS: 0.09134 BCE: 0.01521
# GOOD:  5 BAD:  125
# ...
# VAR EXP: 0.89733 GAUSS: 0.09268 BCE: 0.01559
# GOOD:  10 BAD:  127
# 4 SUB:  [0.09994841 0.10655019 0.10827938]
# CUMULATIVE:  [0.11544224 0.10892908 0.09994841]
# ...
# VAR EXP: 0.91232 GAUSS: 0.07979 BCE: 0.01428
# GOOD:  6 BAD:  120
# ...
# VAR EXP: 0.90677 GAUSS: 0.08432 BCE: 0.01502
# GOOD:  4 BAD:  84
# ...
# VAR EXP: 0.90639 GAUSS: 0.08429 BCE: 0.01586
# GOOD:  14 BAD:  130
# ...
# VAR EXP: 0.9121 GAUSS: 0.07908 BCE: 0.01408
# GOOD:  5 BAD:  111
# 5 SUB:  [0.09407155 0.099342   0.10015675 0.09315639]
# ...

# %%
V_ref = np.load(base_dir+cell_type+"_"+experiment+"/data/"+V_file)[:,:50000].flatten()[T_train:T_train+T_test]
V_two = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub2-0_output.npz")["test"]
V_three = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub3-0_output.npz")["test"]
V_four = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub4-0_output.npz")["test"]
V_five = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub5-3_output.npz")["test"]
V_six = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub6-1_output.npz")["test"]
V_seven = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub7-0_output.npz")["test"]

Z_ref = np.load(base_dir+cell_type+"_"+experiment+"/data/"+Z_file).flatten()[T_train:T_train+T_test]
Z_two = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub2-0_output.npz")["spikes"]
Z_three = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub3-0_output.npz")["spikes"]
Z_four = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub4-0_output.npz")["spikes"]
Z_five = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub5-3_output.npz")["spikes"]
Z_six = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub6-1_output.npz")["spikes"]
Z_seven = np.load(base_dir+cell_type+"_"+experiment+"/greedy/"+model_type+"_sub7-0_output.npz")["spikes"]

# %%
x = np.arange(0,2000,0.2)

fig, axs = plt.subplots(nrows=2, figsize = (20,12))
axs[0].plot(x, V_ref[16000:26000], c="black", label="true")
axs[0].plot(x, V_two[16000:26000], alpha=0.8, label="two")
axs[0].plot(x, V_three[16000:26000], alpha=0.8, label="three")
axs[0].plot(x, V_four[16000:26000], alpha=0.8, label="four")
axs[0].plot(x, V_five[16000:26000], alpha=0.8, label="five")
axs[0].plot(x, V_six[16000:26000], alpha=0.8, label="six")
axs[0].plot(x, V_seven[16000:26000], alpha=0.8, label="seven")
axs[0].legend()

axs[1].scatter(x, Z_ref[16000:26000]*0.5, c="black", label="true", marker="|", s=200)
axs[1].scatter(x, Z_two[16000:26000]*0.51, label="two", marker="|", s=200)
axs[1].scatter(x, Z_three[16000:26000]*0.52, label="three", marker="|", s=200)
axs[1].scatter(x, Z_four[16000:26000]*0.53, label="four", marker="|", s=200)
axs[1].scatter(x, Z_five[16000:26000]*0.54, label="five", marker="|", s=200)
axs[1].scatter(x, Z_six[16000:26000]*0.55, label="six", marker="|", s=200)
axs[1].scatter(x, Z_seven[16000:26000]*0.56, label="seven", marker="|", s=200)
axs[1].legend()
axs[1].set_ylim(0.49,0.57)
# Out:
# (0.49, 0.57)

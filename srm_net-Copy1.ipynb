# %%
from models.srm_net import SRM_Net

import numpy as np
import torch 
import torch.nn as nn
from tqdm import tnrange
import torch.optim as optim
import torch.nn.functional as F
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import explained_variance_score

# %%
base_dir = "/media/hdd01/sklee/"
experiment = "clust4-60"
cell_type = "CA1"

E_neural_file = "Espikes_neural.npy"
I_neural_file = "Ispikes_neural.npy"
Z_file = "spk_loc.npy"
C_syn_e_file = "handsub5_C_syn_e.npy"
C_syn_i_file = "handsub5_C_syn_i.npy"
C_den_file = "handsub5_C_den.npy"

E_neural = np.load(base_dir+cell_type+"_"+experiment+"/data/"+E_neural_file)
I_neural = np.load(base_dir+cell_type+"_"+experiment+"/data/"+I_neural_file)
Z = np.load(base_dir+cell_type+"_"+experiment+"/data/"+Z_file)
C_syn_e = np.load(base_dir+cell_type+"_"+experiment+"/data/"+C_syn_e_file)
C_syn_i = np.load(base_dir+cell_type+"_"+experiment+"/data/"+C_syn_i_file)
C_den = np.load(base_dir+cell_type+"_"+experiment+"/data/"+C_den_file)

E_neural = torch.from_numpy(E_neural)
I_neural = torch.from_numpy(I_neural)
C_syn_e = torch.from_numpy(C_syn_e)
C_syn_i = torch.from_numpy(C_syn_i)
Z = torch.from_numpy(Z)
C_den = torch.from_numpy(C_den)
sub_no = C_den.shape[0]

# %%
T_train = 9 * 1000 * 50
T_test = 1 * 1000 * 50
T_no = 501
save_dir = base_dir+cell_type+"_"+experiment+"/"
device = torch.device("cuda")

batch_size = 1000
iter_no = 10000
epoch_no = iter_no*batch_size//T_train

# %%
W_syn_init = 0
W_spk_init = 0
Tau_syn_init = 0
Tau_spk_init = 0
Delta_syn_init = 0
Delta_spk_init = 0

# %%
Z_train = Z[:T_train].float()
Z_test = Z[T_train:T_train + T_test].to(device).float()
test_E_neural = E_neural[T_train:T_train+T_test].float().to(device)
test_I_neural = I_neural[T_train:T_train+T_test].float().to(device)
train_E_neural = E_neural[:T_train].float()
train_I_neural = I_neural[:T_train].float()
C_syn_e = C_syn_e.float().to(device)
C_syn_i = C_syn_i.float().to(device)
C_den = C_den.float().to(device)

batch_no = (T_train - batch_size) * epoch_no
train_idx = np.empty((epoch_no, T_train//batch_size))
for i in range(epoch_no):
    part_idx = np.arange(0, T_train, batch_size)
    np.random.shuffle(part_idx)
    train_idx[i] = part_idx
train_idx = train_idx.flatten()
train_idx = torch.from_numpy(train_idx)

# %%
model = SRM_Net(C_den, C_syn_e, C_syn_i, T_no, 
            W_syn_init, W_spk_init,
            Tau_syn_init, Tau_spk_init,
            Delta_syn_init, Delta_spk_init,
            device)

optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

model.to(device).float()
print(sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# 120

# %%
tau = 10

t = torch.arange(T_no).to(device)
t_tau = t / tau
kern = t_tau * torch.exp(-t_tau)
kern = torch.flip(kern, [0]).reshape(1,1,-1)

for i in tnrange(iter_no):
    model.train()
    optimizer.zero_grad()
        
    batch_idx = train_idx[i].long()
    batch_E_neural = train_E_neural[batch_idx : batch_idx+batch_size].to(device)
    batch_I_neural = train_I_neural[batch_idx : batch_idx+batch_size].to(device)
    batch_Z = Z_train[batch_idx : batch_idx+batch_size].to(device)
    
    Z_pred, out_filters = model(batch_E_neural, batch_I_neural)
    
    spk_pred = F.conv1d(Z_pred[:,0].reshape(1,1,-1), kern, padding=250).flatten()
    batch_spk = F.conv1d(batch_Z.reshape(1,1,-1), kern, padding=250).flatten()
        
    loss = torch.mean((spk_pred - batch_spk)**2)
    
    loss.backward()
    optimizer.step()
    
    if i%100 == 99:
        model.eval()
        test_Z_pred, test_out_filters = model(test_E_neural, test_I_neural)
        
        test_spk_pred = F.conv1d(test_Z_pred[:,0].reshape(1,1,-1), kern, padding=250).flatten()
        test_spk = F.conv1d(Z_test.reshape(1,1,-1), kern, padding=250).flatten()
         
        test_mse = torch.mean((test_spk_pred - test_spk)**2).item()
        test_var = explained_variance_score(test_spk.cpu().detach().numpy(), test_spk_pred.cpu().detach().numpy())
        
        print(i, 
              "TEST_VAR:", np.round(test_var, 5),
              "TEST_MSE:", np.round(test_mse, 5),
              "TAU_SYN:", np.round(torch.mean(model.Tau_syn_e).item(), 5),
              "TAU_SPK:", np.round(torch.mean(model.Tau_spk).item(), 5),
              "W_SYN:", np.round(torch.mean(model.W_syn_e).item(), 5),
              "W_SPK:", np.round(torch.mean(model.W_spk).item(), 5),
             )
# Out:
# <ipython-input-7-fec06f116a1b>:8: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(iter_no):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# 99 TEST_VAR: -118.04813 TEST_MSE: 0.38061 TAU_SYN: -0.02644 TAU_SPK: -0.01388 W_SYN: 0.0 W_SPK: -0.01413
# 199 TEST_VAR: -83.68652 TEST_MSE: 0.26668 TAU_SYN: -0.04701 TAU_SPK: -0.02201 W_SYN: 0.0 W_SPK: -0.02295
# 299 TEST_VAR: -60.99897 TEST_MSE: 0.19345 TAU_SYN: -0.06348 TAU_SPK: -0.02911 W_SYN: 0.0 W_SPK: -0.03081
# 399 TEST_VAR: -47.19471 TEST_MSE: 0.1497 TAU_SYN: -0.07765 TAU_SPK: -0.03521 W_SYN: 0.0 W_SPK: -0.03766
# 499 TEST_VAR: -36.50096 TEST_MSE: 0.11584 TAU_SYN: -0.09221 TAU_SPK: -0.0411 W_SYN: 0.0 W_SPK: -0.04438
# 599 TEST_VAR: -29.78028 TEST_MSE: 0.09489 TAU_SYN: -0.10439 TAU_SPK: -0.04626 W_SYN: 0.0 W_SPK: -0.05034
# 699 TEST_VAR: -26.14552 TEST_MSE: 0.08278 TAU_SYN: -0.1162 TAU_SPK: -0.05129 W_SYN: 0.0 W_SPK: -0.05624
# 799 TEST_VAR: -23.42282 TEST_MSE: 0.07361 TAU_SYN: -0.12696 TAU_SPK: -0.05607 W_SYN: 0.0 W_SPK: -0.06176
# 899 TEST_VAR: -21.10942 TEST_MSE: 0.06583 TAU_SYN: -0.13573 TAU_SPK: -0.06013 W_SYN: 0.0 W_SPK: -0.06658
# 999 TEST_VAR: -19.43035 TEST_MSE: 0.06007 TAU_SYN: -0.14536 TAU_SPK: -0.0645 W_SYN: 0.0 W_SPK: -0.07183
# 1099 TEST_VAR: -17.67615 TEST_MSE: 0.05405 TAU_SYN: -0.15495 TAU_SPK: -0.06887 W_SYN: 0.0 W_SPK: -0.07708
# 1199 TEST_VAR: -16.22392 TEST_MSE: 0.04915 TAU_SYN: -0.16278 TAU_SPK: -0.07256 W_SYN: 0.0 W_SPK: -0.08152
# 1299 TEST_VAR: -15.67897 TEST_MSE: 0.04636 TAU_SYN: -0.17121 TAU_SPK: -0.07643 W_SYN: 0.0 W_SPK: -0.08618
# 1399 TEST_VAR: -14.22244 TEST_MSE: 0.04173 TAU_SYN: -0.17773 TAU_SPK: -0.07965 W_SYN: 0.0 W_SPK: -0.09011
# 1499 TEST_VAR: -13.18705 TEST_MSE: 0.03826 TAU_SYN: -0.18521 TAU_SPK: -0.08319 W_SYN: 0.0 W_SPK: -0.09448
# 1599 TEST_VAR: -11.68468 TEST_MSE: 0.03362 TAU_SYN: -0.19238 TAU_SPK: -0.08658 W_SYN: 0.0 W_SPK: -0.09864
# 1699 TEST_VAR: -10.72758 TEST_MSE: 0.03056 TAU_SYN: -0.19967 TAU_SPK: -0.09003 W_SYN: 0.0 W_SPK: -0.10285
# 1799 TEST_VAR: -10.24875 TEST_MSE: 0.02893 TAU_SYN: -0.20572 TAU_SPK: -0.0928 W_SYN: 0.0 W_SPK: -0.10627
# 1899 TEST_VAR: -9.32696 TEST_MSE: 0.02611 TAU_SYN: -0.21228 TAU_SPK: -0.09576 W_SYN: 0.0 W_SPK: -0.10994
# 1999 TEST_VAR: -8.68209 TEST_MSE: 0.02406 TAU_SYN: -0.21795 TAU_SPK: -0.09843 W_SYN: 0.0 W_SPK: -0.11327
# 2099 TEST_VAR: -7.60212 TEST_MSE: 0.02107 TAU_SYN: -0.22291 TAU_SPK: -0.10091 W_SYN: 0.0 W_SPK: -0.11631
# 2199 TEST_VAR: -7.01269 TEST_MSE: 0.01941 TAU_SYN: -0.22834 TAU_SPK: -0.10335 W_SYN: 0.0 W_SPK: -0.11939
# 2299 TEST_VAR: -6.01653 TEST_MSE: 0.01675 TAU_SYN: -0.23284 TAU_SPK: -0.10549 W_SYN: 0.0 W_SPK: -0.12211
# 2399 TEST_VAR: -5.87872 TEST_MSE: 0.01629 TAU_SYN: -0.23665 TAU_SPK: -0.10733 W_SYN: 0.0 W_SPK: -0.1244
# 2499 TEST_VAR: -5.24139 TEST_MSE: 0.01461 TAU_SYN: -0.24178 TAU_SPK: -0.10946 W_SYN: 0.0 W_SPK: -0.12708
# 2599 TEST_VAR: -4.64002 TEST_MSE: 0.01309 TAU_SYN: -0.24606 TAU_SPK: -0.11125 W_SYN: 0.0 W_SPK: -0.12929
# 2699 TEST_VAR: -4.30675 TEST_MSE: 0.01219 TAU_SYN: -0.25024 TAU_SPK: -0.11308 W_SYN: 0.0 W_SPK: -0.13157
# 2799 TEST_VAR: -4.02662 TEST_MSE: 0.01143 TAU_SYN: -0.25412 TAU_SPK: -0.11473 W_SYN: 0.0 W_SPK: -0.13364
# 2899 TEST_VAR: -3.24109 TEST_MSE: 0.00956 TAU_SYN: -0.25744 TAU_SPK: -0.11623 W_SYN: 0.0 W_SPK: -0.13548
# 2999 TEST_VAR: -3.05129 TEST_MSE: 0.00908 TAU_SYN: -0.26079 TAU_SPK: -0.11765 W_SYN: 0.0 W_SPK: -0.13722
# 3099 TEST_VAR: -2.80592 TEST_MSE: 0.00848 TAU_SYN: -0.26484 TAU_SPK: -0.11927 W_SYN: 0.0 W_SPK: -0.13926
# 3199 TEST_VAR: -2.49144 TEST_MSE: 0.00776 TAU_SYN: -0.26787 TAU_SPK: -0.1206 W_SYN: 0.0 W_SPK: -0.1409
# 3299 TEST_VAR: -2.05817 TEST_MSE: 0.00671 TAU_SYN: -0.2706 TAU_SPK: -0.12182 W_SYN: 0.0 W_SPK: -0.14236
# 3399 TEST_VAR: -1.69225 TEST_MSE: 0.00586 TAU_SYN: -0.27265 TAU_SPK: -0.12262 W_SYN: 0.0 W_SPK: -0.14342
# 3499 TEST_VAR: -1.6734 TEST_MSE: 0.00582 TAU_SYN: -0.27651 TAU_SPK: -0.12391 W_SYN: 0.0 W_SPK: -0.145
# 3599 TEST_VAR: -1.42127 TEST_MSE: 0.00526 TAU_SYN: -0.27938 TAU_SPK: -0.12502 W_SYN: 0.0 W_SPK: -0.14646
# 3699 TEST_VAR: -1.37719 TEST_MSE: 0.00516 TAU_SYN: -0.28261 TAU_SPK: -0.12609 W_SYN: 0.0 W_SPK: -0.14788
# 3799 TEST_VAR: -1.39285 TEST_MSE: 0.0052 TAU_SYN: -0.28467 TAU_SPK: -0.12695 W_SYN: 0.0 W_SPK: -0.14893
# 3899 TEST_VAR: -1.37719 TEST_MSE: 0.00516 TAU_SYN: -0.28762 TAU_SPK: -0.12809 W_SYN: 0.0 W_SPK: -0.1504
# 3999 TEST_VAR: -1.01433 TEST_MSE: 0.00435 TAU_SYN: -0.29069 TAU_SPK: -0.12915 W_SYN: 0.0 W_SPK: -0.15177
# 4099 TEST_VAR: -1.01452 TEST_MSE: 0.00435 TAU_SYN: -0.29314 TAU_SPK: -0.12998 W_SYN: 0.0 W_SPK: -0.15289
# 4199 TEST_VAR: -1.01452 TEST_MSE: 0.00435 TAU_SYN: -0.29544 TAU_SPK: -0.13074 W_SYN: 0.0 W_SPK: -0.15383
# 4299 TEST_VAR: -1.01452 TEST_MSE: 0.00435 TAU_SYN: -0.29884 TAU_SPK: -0.13187 W_SYN: 0.0 W_SPK: -0.15529
# 4399 TEST_VAR: -1.03688 TEST_MSE: 0.0044 TAU_SYN: -0.30144 TAU_SPK: -0.13269 W_SYN: 0.0 W_SPK: -0.15637
# 4499 TEST_VAR: -0.99483 TEST_MSE: 0.00431 TAU_SYN: -0.30534 TAU_SPK: -0.13389 W_SYN: 0.0 W_SPK: -0.158
# 4599 TEST_VAR: -0.92164 TEST_MSE: 0.00415 TAU_SYN: -0.30945 TAU_SPK: -0.13524 W_SYN: 0.0 W_SPK: -0.15974
# 4699 TEST_VAR: -0.98263 TEST_MSE: 0.00428 TAU_SYN: -0.31172 TAU_SPK: -0.13596 W_SYN: 0.0 W_SPK: -0.16067
# 4799 TEST_VAR: -0.95872 TEST_MSE: 0.00422 TAU_SYN: -0.31556 TAU_SPK: -0.13716 W_SYN: 0.0 W_SPK: -0.16225
# 4899 TEST_VAR: -0.93078 TEST_MSE: 0.00416 TAU_SYN: -0.31807 TAU_SPK: -0.138 W_SYN: 0.0 W_SPK: -0.16341
# 4999 TEST_VAR: -0.88794 TEST_MSE: 0.00407 TAU_SYN: -0.32058 TAU_SPK: -0.13896 W_SYN: 0.0 W_SPK: -0.16468
# 5099 TEST_VAR: -0.84219 TEST_MSE: 0.00397 TAU_SYN: -0.32298 TAU_SPK: -0.13973 W_SYN: 0.0 W_SPK: -0.16566
# 5199 TEST_VAR: -0.84219 TEST_MSE: 0.00397 TAU_SYN: -0.3274 TAU_SPK: -0.14127 W_SYN: 0.0 W_SPK: -0.16771
# 5299 TEST_VAR: -0.75467 TEST_MSE: 0.00378 TAU_SYN: -0.33117 TAU_SPK: -0.14241 W_SYN: 0.0 W_SPK: -0.16928
# 5399 TEST_VAR: -0.77153 TEST_MSE: 0.00382 TAU_SYN: -0.33515 TAU_SPK: -0.14358 W_SYN: 0.0 W_SPK: -0.17086
# 5499 TEST_VAR: -0.77744 TEST_MSE: 0.00383 TAU_SYN: -0.33815 TAU_SPK: -0.14455 W_SYN: 0.0 W_SPK: -0.17215
# 5599 TEST_VAR: -0.73133 TEST_MSE: 0.00373 TAU_SYN: -0.34211 TAU_SPK: -0.14589 W_SYN: 0.0 W_SPK: -0.17395
# 5699 TEST_VAR: -0.73133 TEST_MSE: 0.00373 TAU_SYN: -0.34544 TAU_SPK: -0.14711 W_SYN: 0.0 W_SPK: -0.17568
# 5799 TEST_VAR: -0.73984 TEST_MSE: 0.00375 TAU_SYN: -0.35011 TAU_SPK: -0.14848 W_SYN: 0.0 W_SPK: -0.17747
# 5899 TEST_VAR: -0.71226 TEST_MSE: 0.00369 TAU_SYN: -0.35467 TAU_SPK: -0.14979 W_SYN: 0.0 W_SPK: -0.17921
# 5999 TEST_VAR: -0.71226 TEST_MSE: 0.00369 TAU_SYN: -0.35863 TAU_SPK: -0.15103 W_SYN: 0.0 W_SPK: -0.18094
# 6099 TEST_VAR: -0.75738 TEST_MSE: 0.00379 TAU_SYN: -0.36357 TAU_SPK: -0.15261 W_SYN: 0.0 W_SPK: -0.18302
# 6199 TEST_VAR: -0.73539 TEST_MSE: 0.00374 TAU_SYN: -0.36821 TAU_SPK: -0.15436 W_SYN: 0.0 W_SPK: -0.1854
# 6299 TEST_VAR: -0.78534 TEST_MSE: 0.00385 TAU_SYN: -0.37101 TAU_SPK: -0.15531 W_SYN: 0.0 W_SPK: -0.18673
# 6399 TEST_VAR: -0.78534 TEST_MSE: 0.00385 TAU_SYN: -0.37599 TAU_SPK: -0.15699 W_SYN: 0.0 W_SPK: -0.18898
# 6499 TEST_VAR: -0.73836 TEST_MSE: 0.00374 TAU_SYN: -0.38011 TAU_SPK: -0.15842 W_SYN: 0.0 W_SPK: -0.19096
# 6599 TEST_VAR: -0.6727 TEST_MSE: 0.0036 TAU_SYN: -0.38462 TAU_SPK: -0.15988 W_SYN: 0.0 W_SPK: -0.19298
# 6699 TEST_VAR: -0.71773 TEST_MSE: 0.0037 TAU_SYN: -0.38674 TAU_SPK: -0.16076 W_SYN: 0.0 W_SPK: -0.19429
# 6799 TEST_VAR: -0.72153 TEST_MSE: 0.00371 TAU_SYN: -0.39368 TAU_SPK: -0.1629 W_SYN: 0.0 W_SPK: -0.19717
# 6899 TEST_VAR: -0.72153 TEST_MSE: 0.00371 TAU_SYN: -0.39667 TAU_SPK: -0.16389 W_SYN: 0.0 W_SPK: -0.19869
# 6999 TEST_VAR: -0.69283 TEST_MSE: 0.00364 TAU_SYN: -0.40202 TAU_SPK: -0.16587 W_SYN: 0.0 W_SPK: -0.20146
# 7099 TEST_VAR: -0.68702 TEST_MSE: 0.00363 TAU_SYN: -0.40977 TAU_SPK: -0.16867 W_SYN: 0.0 W_SPK: -0.20517
# 7199 TEST_VAR: -0.68315 TEST_MSE: 0.00362 TAU_SYN: -0.41212 TAU_SPK: -0.16924 W_SYN: 0.0 W_SPK: -0.20608
# 7299 TEST_VAR: -0.69066 TEST_MSE: 0.00364 TAU_SYN: -0.41553 TAU_SPK: -0.1707 W_SYN: 0.0 W_SPK: -0.20794
# 7399 TEST_VAR: -0.67961 TEST_MSE: 0.00362 TAU_SYN: -0.4212 TAU_SPK: -0.17258 W_SYN: 0.0 W_SPK: -0.21042
# 7499 TEST_VAR: -0.66968 TEST_MSE: 0.00359 TAU_SYN: -0.42619 TAU_SPK: -0.17448 W_SYN: 0.0 W_SPK: -0.21313
# 7599 TEST_VAR: -0.72196 TEST_MSE: 0.00371 TAU_SYN: -0.43219 TAU_SPK: -0.17655 W_SYN: 0.0 W_SPK: -0.21626
# 7699 TEST_VAR: -0.79375 TEST_MSE: 0.00386 TAU_SYN: -0.43889 TAU_SPK: -0.17909 W_SYN: 0.0 W_SPK: -0.21994
# 7799 TEST_VAR: -0.76681 TEST_MSE: 0.0038 TAU_SYN: -0.44676 TAU_SPK: -0.18174 W_SYN: 0.0 W_SPK: -0.22378
# 7899 TEST_VAR: -0.76681 TEST_MSE: 0.0038 TAU_SYN: -0.45058 TAU_SPK: -0.18372 W_SYN: 0.0 W_SPK: -0.22643
# 7999 TEST_VAR: -0.74393 TEST_MSE: 0.00375 TAU_SYN: -0.45556 TAU_SPK: -0.18596 W_SYN: 0.0 W_SPK: -0.22957
# 8099 TEST_VAR: -0.70048 TEST_MSE: 0.00366 TAU_SYN: -0.46179 TAU_SPK: -0.18803 W_SYN: 0.0 W_SPK: -0.23251
# 8199 TEST_VAR: -0.7005 TEST_MSE: 0.00366 TAU_SYN: -0.46866 TAU_SPK: -0.19032 W_SYN: 0.0 W_SPK: -0.23592
# 8299 TEST_VAR: -0.67452 TEST_MSE: 0.0036 TAU_SYN: -0.47552 TAU_SPK: -0.19318 W_SYN: 0.0 W_SPK: -0.24012
# 8399 TEST_VAR: -0.65348 TEST_MSE: 0.00356 TAU_SYN: -0.48158 TAU_SPK: -0.19572 W_SYN: 0.0 W_SPK: -0.24388
# 8499 TEST_VAR: -0.67424 TEST_MSE: 0.0036 TAU_SYN: -0.4861 TAU_SPK: -0.19765 W_SYN: 0.0 W_SPK: -0.24661
# 8599 TEST_VAR: -0.61865 TEST_MSE: 0.00348 TAU_SYN: -0.49359 TAU_SPK: -0.20036 W_SYN: 0.0 W_SPK: -0.25072
# 8699 TEST_VAR: -0.66497 TEST_MSE: 0.00358 TAU_SYN: -0.50305 TAU_SPK: -0.20383 W_SYN: 0.0 W_SPK: -0.25586
# 8799 TEST_VAR: -0.66497 TEST_MSE: 0.00358 TAU_SYN: -0.50643 TAU_SPK: -0.20513 W_SYN: 0.0 W_SPK: -0.25799
# 8899 TEST_VAR: -0.62928 TEST_MSE: 0.00351 TAU_SYN: -0.5162 TAU_SPK: -0.20917 W_SYN: 0.0 W_SPK: -0.26417
# 8999 TEST_VAR: -0.6229 TEST_MSE: 0.00349 TAU_SYN: -0.52191 TAU_SPK: -0.21156 W_SYN: 0.0 W_SPK: -0.26779
# 9099 TEST_VAR: -0.60898 TEST_MSE: 0.00346 TAU_SYN: -0.53169 TAU_SPK: -0.21534 W_SYN: 0.0 W_SPK: -0.27331
# 9199 TEST_VAR: -0.72899 TEST_MSE: 0.00372 TAU_SYN: -0.5394 TAU_SPK: -0.21829 W_SYN: 0.0 W_SPK: -0.27791
# 9299 TEST_VAR: -0.60217 TEST_MSE: 0.00345 TAU_SYN: -0.54544 TAU_SPK: -0.22084 W_SYN: 0.0 W_SPK: -0.28188
# 9399 TEST_VAR: -0.62875 TEST_MSE: 0.00351 TAU_SYN: -0.55114 TAU_SPK: -0.22365 W_SYN: 0.0 W_SPK: -0.28617
# 9499 TEST_VAR: -0.61526 TEST_MSE: 0.00348 TAU_SYN: -0.55917 TAU_SPK: -0.22727 W_SYN: 0.0 W_SPK: -0.29159
# 9599 TEST_VAR: -0.65206 TEST_MSE: 0.00356 TAU_SYN: -0.56795 TAU_SPK: -0.23103 W_SYN: 0.0 W_SPK: -0.29714
# 9699 TEST_VAR: -0.65762 TEST_MSE: 0.00357 TAU_SYN: -0.57678 TAU_SPK: -0.23518 W_SYN: 0.0 W_SPK: -0.30343
# 9799 TEST_VAR: -0.65352 TEST_MSE: 0.00356 TAU_SYN: -0.58486 TAU_SPK: -0.23806 W_SYN: 0.0 W_SPK: -0.30802
# 9899 TEST_VAR: -0.62741 TEST_MSE: 0.0035 TAU_SYN: -0.59171 TAU_SPK: -0.24112 W_SYN: 0.0 W_SPK: -0.31279
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-fec06f116a1b> in <module>
#      10     optimizer.zero_grad()
#      11
# ---> 12     batch_idx = train_idx[i].long()
#      13     batch_E_neural = train_E_neural[batch_idx : batch_idx+batch_size].to(device)
#      14     batch_I_neural = train_I_neural[batch_idx : batch_idx+batch_size].to(device)
#
# IndexError: index 9900 is out of bounds for dimension 0 with size 9900

# %%
plt.figure(figsize = (15,5))
plt.plot(test_spk.cpu().detach().numpy()[16000:26000])
plt.plot(test_spk_pred.cpu().detach().numpy()[16000:26000])

# %%
plt.figure(figsize = (15,5))
plt.plot(test_spk.cpu().detach().numpy()[16000:26000][2000:8000])
plt.plot(test_spk_pred.cpu().detach().numpy()[16000:26000][2000:8000])

# %%
plt.figure(figsize = (15,5))
plt.plot(test_spk.cpu().detach().numpy())
plt.plot(test_spk_pred.cpu().detach().numpy())

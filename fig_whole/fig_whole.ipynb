# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.sparse
from matplotlib import cm
import matplotlib as mpl
from cycler import cycler
from matplotlib import rc
import scipy.stats
from sklearn.metrics import explained_variance_score
import seaborn as sns

# %% [markdown]
# ## full figure

# %%
true4_na_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust4-60/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy"))
true4_na = np.load("/media/hdd01/sklee/CA1_clust4-60/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1_set1.npy")[-20:,:50000]
true8_na_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust8-30/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true8_na = np.load("/media/hdd01/sklee/CA1_clust8-30/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]
true12_na_mean = np.mean(np.load("/media/hdd01/sklee/CA1_clust12-20/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy"))
true12_na = np.load("/media/hdd01/sklee/CA1_clust12-20/data/vdata_T10_Ne2000_gA0.6_tauA1_gN0.8_Ni200_gG0.1_gB0.1_Er0.5_Ir7.4_random_NR_rep1000_stimseed1.npy")[-20:,:50000]

one4_na_test = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h1_output.npz")["test"] + true4_na_mean
two4_na_test = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h2_output.npz")["test"] + true4_na_mean
gru4_na_test = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/gru_s10_h20_output.npz")["test"] + true4_na_mean
one8_na_test = np.load("/media/hdd01/sklee/CA1_clust8-30/whole/glm_s14_h1_output.npz")["test"] + true8_na_mean
two8_na_test = np.load("/media/hdd01/sklee/CA1_clust8-30/whole/glm_s14_h2_output.npz")["test"] + true8_na_mean
gru8_na_test = np.load("/media/hdd01/sklee/CA1_clust8-30/whole/gru_s14_h20_output.npz")["test"] + true8_na_mean
one12_na_test = np.load("/media/hdd01/sklee/CA1_clust12-20/whole/glm_s18_h1_output.npz")["test"] + true12_na_mean
two12_na_test = np.load("/media/hdd01/sklee/CA1_clust12-20/whole/glm_s18_h2_output.npz")["test"] + true12_na_mean
gru12_na_test = np.load("/media/hdd01/sklee/CA1_clust12-20/whole/gru_s18_h20_output.npz")["test"] + true12_na_mean

two4_na_ekern = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h2_output.npz")["e_kern"]
two4_na_ikern = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h2_output.npz")["i_kern"]
two4_na_nonlin = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h2_output.npz")["nonlin_in"]

one4_na_ekern = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h1_output.npz")["e_kern"]
one4_na_ikern = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h1_output.npz")["i_kern"]
one4_na_nonlin = np.load("/media/hdd01/sklee/CA1_clust4-60/whole/glm_s10_h1_output.npz")["nonlin_in"]

one4_error = true4_na - one4_na_test
two4_error = true4_na - two4_na_test
gru4_error = true4_na - gru4_na_test
diff4 = np.load("/media/hdd01/sklee/CA1_clust4-60/data/V_diff_stimseed1_set1.npy")[-20*50000:].reshape(-1,50000)
gru8_error = true8_na - gru8_na_test
diff8 = np.load("/media/hdd01/sklee/CA1_clust8-30/data/V_diff_stimseed1.npy")[-20*50000:].reshape(-1,50000)
gru12_error = true12_na - gru12_na_test
diff12 = np.load("/media/hdd01/sklee/CA1_clust12-20/data/V_diff_stimseed1.npy")[-20*50000:].reshape(-1,50000)

# %%
var_exp_array = np.zeros((3,3,20))

for i in range(20):
    var_exp_array[0,0,i] = explained_variance_score(true4_na[i], one4_na_test[i])
    var_exp_array[0,1,i] = explained_variance_score(true4_na[i], two4_na_test[i])
    var_exp_array[0,2,i] = explained_variance_score(true4_na[i], gru4_na_test[i])
    var_exp_array[1,0,i] = explained_variance_score(true8_na[i], one8_na_test[i])
    var_exp_array[1,1,i] = explained_variance_score(true8_na[i], two8_na_test[i])
    var_exp_array[1,2,i] = explained_variance_score(true8_na[i], gru8_na_test[i])
    var_exp_array[2,0,i] = explained_variance_score(true12_na[i], one12_na_test[i])
    var_exp_array[2,1,i] = explained_variance_score(true12_na[i], two12_na_test[i])
    var_exp_array[2,2,i] = explained_variance_score(true12_na[i], gru12_na_test[i])
    
thresh_bin_no = 250
bin_no = 250

na_means = np.zeros((thresh_bin_no, 4))
na_stds = np.zeros((thresh_bin_no, 4))
na_bins = np.linspace(np.min(true4_na), np.max(true4_na), thresh_bin_no+1)

for i in range(thresh_bin_no):
    na_idx = np.where((true4_na.flatten() >= na_bins[i]) & (true4_na.flatten() < na_bins[i+1]))[0]
    na_means[i,1] = np.mean(one4_na_test.flatten()[na_idx])
    na_means[i,2] = np.mean(two4_na_test.flatten()[na_idx])
    na_means[i,3] = np.mean(gru4_na_test.flatten()[na_idx])
    na_means[i,0] = (na_bins[i] + na_bins[i+1])/2
    
    na_stds[i,0] = (na_bins[i] + na_bins[i+1])/2
    na_stds[i,1] = np.std(one4_na_test.flatten()[na_idx])
    na_stds[i,2] = np.std(two4_na_test.flatten()[na_idx])
    na_stds[i,3] = np.std(gru4_na_test.flatten()[na_idx])
    
error_diff_4, diff4_bins, error4_bins = np.histogram2d(diff4.flatten(), gru4_error.flatten(), bins=40)
error_diff_8, diff8_bins, error8_bins = np.histogram2d(diff8.flatten(), gru8_error.flatten(), bins=40)
error_diff_12, diff12_bins, error12_bins = np.histogram2d(diff12.flatten(), gru12_error.flatten(), bins=40)
# Out:
# /home/sklee/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/sklee/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/sklee/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sklee/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/sklee/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
plt.rcParams['font.size'] = '15'

fig = plt.figure(constrained_layout=True, figsize = (16,8.5))
gs = fig.add_gridspec(4,12, wspace=3, hspace=1.5)
ax1 = fig.add_subplot(gs[0,:6])
ax2 = fig.add_subplot(gs[:2,6:9])
ax3 = fig.add_subplot(gs[:2,9:12])
#ax4 = fig.add_subplot(gs[2,:3])
#ax5 = fig.add_subplot(gs[2,3:6])
#ax6 = fig.add_subplot(gs[2,6:9])
#ax7 = fig.add_subplot(gs[2,9:])
ax8 = fig.add_subplot(gs[1,:6])
ax9 = fig.add_subplot(gs[2:,:4])
ax10 = fig.add_subplot(gs[2:,4:8])
ax11 = fig.add_subplot(gs[2:,8:12])

ax1.plot(np.arange(0,0.6,1/5000), true4_na[-2][22000:25000], linewidth=1, color="black", label="target")
ax1.plot(np.arange(0,0.6,1/5000), one4_na_test[-2][22000:25000], linewidth=1, color="green", label="static", alpha=0.6)
ax1.plot(np.arange(0,0.6,1/5000), two4_na_test[-2][22000:25000], linewidth=1, color="blue", label="static w/ multiplex", alpha=0.6)
ax1.plot(np.arange(0,0.6,1/5000), gru4_na_test[-2][22000:25000], linewidth=1, color="red", label="dynamic", alpha=0.6)
#ax1.legend(loc=(0.03,-1.3), frameon=False, fontsize=11)
ax1.margins(x=0.005, y=0.005)
ax1.spines.right.set_visible(False)
ax1.spines.top.set_visible(False)
ax1.spines.bottom.set_visible(False)
ax1.set_xticks([])
ax1.set_yticks([-65,-58])
ax1.set_ylim(-65,-58)
ax1.set_ylabel("voltage (mV)")
#ax1.set_xlabel("Time (s)")
ax1.set_title("$\mathregular{v_{soma}}$ & predictions")

colors = ["green", "blue", "red"]
cap_colors = ["green", "green", "blue", "blue", "red", "red"]

# first boxplot pair
bp = ax2.boxplot(var_exp_array[0].T, positions = [1,2,3], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])
    
# second boxplot pair
bp = ax2.boxplot(var_exp_array[1].T, positions = [5,6,7], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])
    
# thrid boxplot pair
bp = ax2.boxplot(var_exp_array[2].T, positions = [9,10,11], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])


ax2.set_ylim(0,1)
ax2.set_xticks([2,6,10])
ax2.tick_params(axis="x", length=0)
ax2.set_xticklabels(["4", "8", "12"])
ax2.set_xlabel("number of clusters")
ax2.set_ylabel("variance explained")
ax2.margins(x=0.005, y=0.005)
ax2.spines.right.set_visible(False)
ax2.spines.top.set_visible(False)
ax2.spines.bottom.set_visible(False)

"""
ins = ax2.inset_axes([0.22,0.27,0.8,0.35])
bp = ins.boxplot(var_exp_array[0].T, positions = [1,2,3], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])
    
# second boxplot pair
bp = ins.boxplot(var_exp_array[1].T, positions = [5,6,7], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])
    
# thrid boxplot pair
bp = ins.boxplot(var_exp_array[2].T, positions = [9,10,11], widths = 0.6, patch_artist=True)
for i in range(var_exp_array[0].shape[0]):
    plt.setp(bp['boxes'][i], facecolor=colors[i])
    plt.setp(bp['boxes'][i], alpha=0.5)
    plt.setp(bp["fliers"][i], markeredgecolor=colors[i])
    plt.setp(bp["boxes"][i], color=colors[i])
    plt.setp(bp["medians"][i], color=colors[i])
for i in range(var_exp_array[0].shape[0]*2):
    plt.setp(bp['whiskers'][i], color=cap_colors[i])
    plt.setp(bp['caps'][i], color=cap_colors[i])

ins.set_ylim(0.94,1)
ins.set_xticks([])
ins.margins(x=0.005, y=0.005)
ins.spines.right.set_visible(False)
ins.spines.top.set_visible(False)
ins.spines.bottom.set_visible(False)
ins.set_yticks([0.94,1])
"""

hB, = ax2.plot(1,1,'blue')
hR, = ax2.plot(1,1,'red')
hG, = ax2.plot(1,1,'green')
#ax2.legend((hG, hB, hR),('static', 'static w/ multiplex', 'dynamic'), loc=(0.3,0.75), fontsize=8, frameon=False)
hB.set_visible(False)
hR.set_visible(False)
hG.set_visible(False)

ax3.plot(na_means[:,0],na_means[:,1], linewidth=1, color="green", label="static")
ax3.plot(na_means[:,0],na_means[:,2], linewidth=1, color="blue", label="static w/ multiplex")
ax3.plot(na_means[:,0],na_means[:,3], linewidth=1, color="red", label="dynamic")
ax3.fill_between(na_means[:,0], na_means[:,1]-na_stds[:,1], na_means[:,1]+na_stds[:,1], color="green", alpha=0.2)
ax3.fill_between(na_means[:,0], na_means[:,2]-na_stds[:,2], na_means[:,2]+na_stds[:,2], color="blue", alpha=0.2)
ax3.fill_between(na_means[:,0], na_means[:,3]-na_stds[:,3], na_means[:,3]+na_stds[:,3], color="red", alpha=0.2)
ax3.plot(na_means[:,0], na_means[:,0], linewidth=1, color="black", linestyle="--")
ax3.margins(x=0.005, y=0.005)
ax3.spines.right.set_visible(False)
ax3.spines.top.set_visible(False)
ax3.set_xlabel("true voltage (mV)")
ax3.set_ylabel("predicted voltage (mV)")
#ax3.legend(loc="upper left", fontsize=8, frameon=False)
ax3.set_xticks(np.arange(-68,-55.9,4))
ax3.set_yticks(np.arange(-68,-55.9,4))
ax3.set_xlim(-68,-55.8)
ax3.set_ylim(-68,-55.8)

inset_size = -50
ins = ax3.inset_axes([0.65,0.1,0.35,0.4])
ins.plot(na_means[inset_size:,0],na_means[inset_size:,1], linewidth=1, color="green", label="static")
ins.plot(na_means[inset_size:,0],na_means[inset_size:,2], linewidth=1, color="blue", label="static w/ multiplex")
ins.plot(na_means[inset_size:,0],na_means[inset_size:,3], linewidth=1, color="red", label="dynamic")
ins.fill_between(na_means[inset_size:,0], na_means[inset_size:,1]-na_stds[inset_size:,1],
                 na_means[inset_size:,1]+na_stds[inset_size:,1], color="green", alpha=0.2)
ins.fill_between(na_means[inset_size:,0], na_means[inset_size:,2]-na_stds[inset_size:,2],
                 na_means[inset_size:,2]+na_stds[inset_size:,2], color="blue", alpha=0.2)
ins.fill_between(na_means[inset_size:,0], na_means[inset_size:,3]-na_stds[inset_size:,3],
                 na_means[inset_size:,3]+na_stds[inset_size:,3], color="red", alpha=0.2)
ins.plot(na_means[inset_size:,0], na_means[inset_size:,0], linewidth=1, color="black", linestyle="--")
ins.margins(x=0.005, y=0.005)
ins.spines.right.set_visible(False)
ins.spines.top.set_visible(False)
ins.set_ylim(-60,-57)
ins.set_xlim(-59,-57)
ins.set_xticks([])
ins.set_yticks([])

ax8.plot(np.arange(0,0.6,1/5000), diff4[-2][22000:25000], linewidth=1.5, color="black", label="target")
ax8.plot(np.arange(0,0.6,1/5000), one4_error[-2][22000:25000], linewidth=0.5, color="green", label="static error")
ax8.plot(np.arange(0,0.6,1/5000), two4_error[-2][22000:25000], linewidth=0.5, color="blue", label="static w/ multiplex error")
ax8.plot(np.arange(0,0.6,1/5000), gru4_error[-2][22000:25000], linewidth=0.5, color="red", label="dynamic error")
#ax8.legend(loc=(0.7,0.55), fontsize=11, frameon=False)
ax8.spines.right.set_visible(False)
ax8.spines.top.set_visible(False)
ax8.spines.bottom.set_visible(False)
ax8.set_xticks([])
ax8.set_ylim(-1.5,3)
ax8.spines.left.set_bounds((-1, 3))
ax8.set_yticks([-1,0,3])
#ax8.set_xlabel("Time (ms)")
ax8.set_ylabel("voltage (mV)")
ax8.margins(x=0.005, y=0.005)
ax8.set_title("$\mathregular{v_{Na}}$ & prediction errors")

im9 = ax9.imshow(np.flipud(np.log10(error_diff_4).T), extent=[diff4_bins[0], diff4_bins[-1], error4_bins[0], error4_bins[-1]], cmap="jet")
#fig.colorbar(im9, ax=ax9, shrink=0.6)
coeff4 = np.corrcoef(diff4.flatten(), gru4_error.flatten())[0][1]
print(coeff4)
ax9.set_title("4 clusters")
ax9.set_ylabel("prediction error (mV)")
ax9.set_xlabel("$\mathregular{v_{Na}}$ (mV)")
ax9.spines.right.set_visible(False)
ax9.spines.top.set_visible(False)
ax9.set_xticks(np.arange(-1,4.1,1))
ax9.set_yticks(np.arange(-2,3.1,1))
ax9.set_xlim(-1,4)
ax9.set_ylim(-2,3)
ax9.set_aspect(1)
ax9.annotate("R² = "+str(np.round(coeff4,4)), xy=(0.5,0.9),  xycoords='axes fraction',
            size=14, ha='right', va='top')

im10 = ax10.imshow(np.flipud(np.log10(error_diff_8).T), extent=[diff8_bins[0], diff8_bins[-1], error8_bins[0], error8_bins[-1]], cmap="jet")
#fig.colorbar(im10, ax=ax10)
coeff8 = np.corrcoef(diff8.flatten(), gru8_error.flatten())[0][1]
print(coeff8)
ax10.set_title("8 clusters")
ax10.set_xlabel("$\mathregular{v_{Na}}$ (mV)")
ax10.set_ylabel("prediction error (mV)")
ax10.spines.right.set_visible(False)
ax10.spines.top.set_visible(False)
ax10.set_xticks(np.arange(-1,4.1,1))
ax10.set_yticks(np.arange(-2,4.1,1))
ax10.set_xlim(-1,4)
ax10.set_ylim(-2,4)
ax10.set_aspect(1)
ax10.annotate("R² = "+str(np.round(coeff8,4)), xy=(0.5,0.9),  xycoords='axes fraction',
            size=14, ha='right', va='top')

im11 = ax11.imshow(np.flipud(np.log10(error_diff_12).T), extent=[diff12_bins[0], diff12_bins[-1], error12_bins[0], error12_bins[-1]], cmap="jet")
cbar = fig.colorbar(im11, ax=[ax9,ax10,ax11], shrink=0.8, pad=0.025, fraction=0.01, ticks=[0,1,2,3,4,5])
cbar.ax.set_yticklabels(["$\mathregular{10^0}$","$\mathregular{10^1}$",
                         "$\mathregular{10^2}$","$\mathregular{10^3}$",
                         "$\mathregular{10^4}$","$\mathregular{10^5}$"])
coeff12 = np.corrcoef(diff12.flatten(), gru12_error.flatten())[0][1]
print(coeff12)
ax11.set_title("12 clusters")
ax11.set_xlabel("$\mathregular{v_{Na}}$ (mV)")
ax11.set_ylabel("prediction error (mV)")
ax11.spines.right.set_visible(False)
ax11.spines.top.set_visible(False)
ax11.set_xticks(np.arange(-1,3.1,1))
ax11.set_yticks(np.arange(-2,3.1,1))
ax11.set_xlim(-1,3)
ax11.set_ylim(-2,3)
ax11.set_aspect(1)
ax11.annotate("R² = "+str(np.round(coeff12,4)), xy=(0.55,0.9),  xycoords='axes fraction',
            size=14, ha='right', va='top')

fig.tight_layout()
#plt.show()
#fig.savefig("/home/sklee/dendrite/fig_whole/fig_whole_raw.pdf", bbox_inches="tight", transparent=True)
# Out:
# /tmp/ipykernel_15010/1638240218.py:196: RuntimeWarning: divide by zero encountered in log10
#   im9 = ax9.imshow(np.flipud(np.log10(error_diff_4).T), extent=[diff4_bins[0], diff4_bins[-1], error4_bins[0], error4_bins[-1]], cmap="jet")
# /tmp/ipykernel_15010/1638240218.py:213: RuntimeWarning: divide by zero encountered in log10
#   im10 = ax10.imshow(np.flipud(np.log10(error_diff_8).T), extent=[diff8_bins[0], diff8_bins[-1], error8_bins[0], error8_bins[-1]], cmap="jet")
# /tmp/ipykernel_15010/1638240218.py:230: RuntimeWarning: divide by zero encountered in log10
#   im11 = ax11.imshow(np.flipud(np.log10(error_diff_12).T), extent=[diff12_bins[0], diff12_bins[-1], error12_bins[0], error12_bins[-1]], cmap="jet")
# /tmp/ipykernel_15010/1638240218.py:250: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# 0.48537307102342775
# 0.6551369154037239
# 0.48454908013683723
# ...
